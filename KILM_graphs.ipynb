# %% [markdown]
# ### Некоторые из основных показателей трудового рынка, без распределения по полу, возрасту или сектору

# %%
print_ilo_stats(0, 
                tmp,
                ['ref_area.label', 'indicator.label', 'time', 'obs_value', 'classif1.label'],
                ['indicator.label', 'classif1.label']
               )

# %%
print_ilo_stats(0, 
                df[df['indicator.label'].isin([
                    'Incidence of part-time employment by sex -- Common definition (%)',
                    'Share of youth not in employment, education or training (NEET) by sex (%)'
                ])],
                ['ref_area.label', 'indicator.label', 'time', 'obs_value'],
                ['indicator.label']
               )

# %%
print_ilo_stats(0, 
                df[(df['indicator.label'] == 'Employment distribution by hours actually worked (by sex) (%)') &
                df['classif1.label'].isin([
                     'Hour bands: 15-29',
                     'Hour bands: 30-34',
                     'Hour bands: 35-39',
                     'Hour bands: 40-48',
                     'Hour bands: 49+',
                     'Hour bands: No hours actually worked'])
                  ],
                ['ref_area.label', 'indicator.label', 'time', 'obs_value', 'classif1.label'],
                ['indicator.label', 'classif1.label']
               )

# %%
print_ilo_stats(0, 
                df[(df['indicator.label'] == 'Unemployment distribution by duration (by sex and age) (%)') &
                (df['classif1.label'] == 'Aggregate age bands: Total') &
                df['classif2.label'].isin(['Detailed duration: Less than 1 month',
                   'Detailed duration: 1 month to less than 3 months',
                   'Detailed duration: 3 months to less than 6 months',
                   'Detailed duration: 6 months to less than 12 months',
                   'Detailed duration: 12 months to less than 24 months',
                   'Detailed duration: 24 months or more'])
                ],
                ['ref_area.label', 'indicator.label', 'time', 'obs_value', 'classif2.label'],
                ['indicator.label', 'classif2.label']
               )

# %%
df_kilm
