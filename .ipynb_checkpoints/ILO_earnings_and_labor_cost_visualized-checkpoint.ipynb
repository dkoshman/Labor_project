# %%
print_ilo_stats(0, 
                df_cost_earnings, 
                ['ref_area.label', 'indicator.label', 'time', 'obs_value', 'classif1.label'],
                ['indicator.label', 'classif1.label']
               )

# %%
print_ilo_stats(1, 
                df_cost_earnings, 
                ['ref_area.label', 'indicator.label', 'time', 'obs_value', 'classif1.label'],
                ['indicator.label', 'classif1.label']
               )
